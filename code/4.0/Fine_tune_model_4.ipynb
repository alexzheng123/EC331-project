# %% [markdown]
# # Run this notebook on Google Colab

# %%
# !pip install optuna --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 7.0 MB/s eta 0:00:00

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import random
import tensorflow as tf
from math import sqrt
import math

# Import Optuna for hyperparameter tuning
import optuna

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from keras.models import Sequential
from keras.layers import GRU, Dropout, Dense
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ensure TensorFlow is using GPU
device_name = tf.test.gpu_device_name()
if device_name:
    print(f"GPU Detected: {device_name}")
else:
    print("No GPU found. Training may be slow.")
# Out:
# GPU Detected: /device:GPU:0

# %%
# Train-val-test split (70% training, 20% validation, 10% test)
TRAIN_RATIO = 0.70
VAL_RATIO = 0.20
TEST_RATIO = 0.10

assert math.isclose(TRAIN_RATIO + VAL_RATIO + TEST_RATIO, 1.0), "Splits must sum to 1.0"

# %%
# Update dataset path for Google Drive
data_path = "/content/drive/My Drive/Colab Notebooks/4.0/Bitcoin_data_full.csv"
data = pd.read_csv(data_path, index_col=0, parse_dates=True) # Set index to datetime

# Only select relevant data
data = data.drop(columns=['Volume BTC', 'VIX', 'Oil'])
data
# Out:
#                         open     high      low    close     Volume USD  \
# date
# 2024-01-31 00:00:00  42945.0  42989.0  42933.0  42984.0  221828.915894
# 2024-01-31 00:01:00  42981.0  43056.0  42981.0  43056.0  343126.169175
# 2024-01-31 00:02:00  43056.0  43098.0  43022.0  43022.0  411354.902045
# 2024-01-31 00:03:00  43019.0  43029.0  43005.0  43005.0   25723.117782
# 2024-01-31 00:04:00  43002.0  43031.0  43002.0  43006.0   40508.530194
# ...                      ...      ...      ...      ...            ...
# 2024-12-31 23:55:00  93476.0  93476.0  93471.0  93471.0   16805.981112
# 2024-12-31 23:56:00  93469.0  93469.0  93469.0  93469.0    2000.236600
# 2024-12-31 23:57:00  93462.0  93462.0  93413.0  93427.0    3246.554616
# 2024-12-31 23:58:00  93427.0  93427.0  93427.0  93427.0       0.000000
# 2024-12-31 23:59:00  93381.0  93381.0  93381.0  93381.0     496.869095
#
#                        SP500      CPI       Gold  fear_n_greed_index
# date
# 2024-01-31 00:00:00  4845.65  308.417  2037.1899                60.0
# 2024-01-31 00:01:00  4845.65  308.417  2037.1899                60.0
# 2024-01-31 00:02:00  4845.65  308.417  2037.1899                60.0
# 2024-01-31 00:03:00  4845.65  308.417  2037.1899                60.0
# 2024-01-31 00:04:00  4845.65  308.417  2037.1899                60.0
# ...                      ...      ...        ...                 ...
# 2024-12-31 23:55:00  5881.63  315.605  2623.8101                64.0
# 2024-12-31 23:56:00  5881.63  315.605  2623.8101                64.0
# 2024-12-31 23:57:00  5881.63  315.605  2623.8101                64.0
# 2024-12-31 23:58:00  5881.63  315.605  2623.8101                64.0
# 2024-12-31 23:59:00  5881.63  315.605  2623.8101                64.0
#
# [468137 rows x 9 columns]

# %%
print("Missing values:\n", data.isna().sum())
# Out:
# Missing values:
#  open                  0
# high                  0
# low                   0
# close                 0
# Volume USD            0
# SP500                 0
# CPI                   0
# Gold                  0
# fear_n_greed_index    0
# dtype: int64

# %%
# Identify target column index
target_col_idx = data.columns.get_loc('close')

# %%
# Train-val-test split
train_index = int(len(data) * TRAIN_RATIO)
val_index = train_index + int(len(data) * VAL_RATIO)

train_data = data.iloc[:train_index]
val_data = data.iloc[train_index:val_index]
test_data = data.iloc[val_index:]

print("Train shape:", train_data.shape)
print("Validation shape:", val_data.shape)
print("Test shape:", test_data.shape)
# Out:
# Train shape: (327695, 9)
# Validation shape: (93627, 9)
# Test shape: (46815, 9)

# %%
# Fit scaler ONLY on training data
scaler = MinMaxScaler()
scaler.fit(train_data)

# Transform datasets
train_scaled = scaler.transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# Function to create sequences for time series forecasting
def create_sequences(data_array, window_size, target_col_idx):
    X, y = [], []
    for i in range(len(data_array) - window_size):
        X.append(data_array[i:(i + window_size), :])
        y.append(data_array[i + window_size, target_col_idx])
    return np.array(X), np.array(y)

# %%
# Function to inverse transform predictions
def inverse_transform_predictions(predicted_scaled, y_actual_scaled, scaler, train_data, target_col_idx):
    predicted_full = np.zeros((predicted_scaled.shape[0], train_data.shape[1]))
    y_actual_full = np.zeros((y_actual_scaled.shape[0], train_data.shape[1]))

    predicted_full[:, target_col_idx] = predicted_scaled[:, 0]
    y_actual_full[:, target_col_idx] = y_actual_scaled

    predicted_inverse = scaler.inverse_transform(predicted_full)[:, target_col_idx]
    y_actual_inverse = scaler.inverse_transform(y_actual_full)[:, target_col_idx]

    return predicted_inverse, y_actual_inverse

# %%
# Objective function for Optuna
def objective(trial):
    """
    Objective function for Optuna optimization.

    Returns:
    - Validation RMSE (Root Mean Squared Error).
    """
    # Suggest hyperparameters
    window_size = trial.suggest_int("WINDOW_SIZE", 30, 120, step=10)
    num_neurons = trial.suggest_int("NUM_NEURONS", 32, 128, step=16)
    dropout_rate = trial.suggest_float("DROPOUT_RATE", 0.1, 0.5, step=0.05)
    patience = trial.suggest_int("PATIENCE", 3, 10)
    epochs = trial.suggest_int("EPOCHS", 50, 200, step=10)
    batch_size = trial.suggest_categorical("BATCH_SIZE", [32, 64, 128, 256, 512])
    learning_rate = trial.suggest_loguniform("LEARNING_RATE", 1e-5, 1e-2)

    # Create sequences
    X_train, y_train = create_sequences(train_scaled, window_size, target_col_idx)
    X_val, y_val = create_sequences(val_scaled, window_size, target_col_idx)

    # Build the GRU model
    model = Sequential([
        GRU(num_neurons, input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(dropout_rate),
        Dense(1)
    ])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss="mean_squared_error")

    # Early stopping
    early_stopping = EarlyStopping(monitor="val_loss", patience=patience, restore_best_weights=True, verbose=0)

    # Train the model with GPU support
    with tf.device('/device:GPU:0'):
        model.fit(
            X_train, y_train,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_val, y_val),
            callbacks=[early_stopping],
            verbose=0
        )

    # Predict on validation set
    y_val_pred_scaled = model.predict(X_val, verbose=0)

    # Inverse transform predictions
    predicted_val_inverse, y_val_inverse = inverse_transform_predictions(
        predicted_scaled=y_val_pred_scaled,
        y_actual_scaled=y_val,
        scaler=scaler,
        train_data=train_data,
        target_col_idx=target_col_idx
    )

    # Compute validation RMSE
    val_rmse = sqrt(mean_squared_error(y_val_inverse, predicted_val_inverse))

    return val_rmse  # Minimize RMSE

# %%
# Run Optuna optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=20)  # Run for 20 trials

# Display best parameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# [I 2025-02-14 23:59:51,708] A new study created in memory with name: no-name-f0b0d54a-9be5-41d0-b4c0-edf5f9508594
# [I 2025-02-15 00:01:35,567] Trial 0 finished with value: 348.2756044093707 and parameters: {'WINDOW_SIZE': 30, 'NUM_NEURONS': 96, 'DROPOUT_RATE': 0.15000000000000002, 'PATIENCE': 7, 'EPOCHS': 90, 'BATCH_SIZE': 512, 'LEARNING_RATE': 0.00038916755779283053}. Best is trial 0 with value: 348.2756044093707.
# [I 2025-02-15 00:03:38,943] Trial 1 finished with value: 208.3400306994646 and parameters: {'WINDOW_SIZE': 100, 'NUM_NEURONS': 128, 'DROPOUT_RATE': 0.15000000000000002, 'PATIENCE': 4, 'EPOCHS': 170, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.003979710907322783}. Best is trial 1 with value: 208.3400306994646.
# [I 2025-02-15 00:05:17,406] Trial 2 finished with value: 187.21213868552803 and parameters: {'WINDOW_SIZE': 120, 'NUM_NEURONS': 80, 'DROPOUT_RATE': 0.2, 'PATIENCE': 6, 'EPOCHS': 60, 'BATCH_SIZE': 256, 'LEARNING_RATE': 0.0003571835778058608}. Best is trial 2 with value: 187.21213868552803.
# [I 2025-02-15 00:08:28,210] Trial 3 finished with value: 662.1782186219293 and parameters: {'WINDOW_SIZE': 70, 'NUM_NEURONS': 64, 'DROPOUT_RATE': 0.5, 'PATIENCE': 9, 'EPOCHS': 180, 'BATCH_SIZE': 128, 'LEARNING_RATE': 1.649730448908711e-05}. Best is trial 2 with value: 187.21213868552803.
# [I 2025-02-15 00:09:11,491] Trial 4 finished with value: 623.1865371476171 and parameters: {'WINDOW_SIZE': 80, 'NUM_NEURONS': 48, 'DROPOUT_RATE': 0.30000000000000004, 'PATIENCE': 4, 'EPOCHS': 120, 'BATCH_SIZE': 512, 'LEARNING_RATE': 0.0005337980465973066}. Best is trial 2 with value: 187.21213868552803.
# [I 2025-02-15 00:11:25,035] Trial 5 finished with value: 107.76218679738334 and parameters: {'WINDOW_SIZE': 50, 'NUM_NEURONS': 64, 'DROPOUT_RATE': 0.35, 'PATIENCE': 6, 'EPOCHS': 70, 'BATCH_SIZE': 512, 'LEARNING_RATE': 4.6624377629954426e-05}. Best is trial 5 with value: 107.76218679738334.
# [I 2025-02-15 00:19:21,917] Trial 6 finished with value: 382.68912129563427 and parameters: {'WINDOW_SIZE': 70, 'NUM_NEURONS': 96, 'DROPOUT_RATE': 0.35, 'PATIENCE': 6, 'EPOCHS': 70, 'BATCH_SIZE': 32, 'LEARNING_RATE': 0.00010692493120924945}. Best is trial 5 with value: 107.76218679738334.
# [I 2025-02-15 00:24:03,853] Trial 7 finished with value: 165.49079828868915 and parameters: {'WINDOW_SIZE': 30, 'NUM_NEURONS': 112, 'DROPOUT_RATE': 0.35, 'PATIENCE': 10, 'EPOCHS': 130, 'BATCH_SIZE': 64, 'LEARNING_RATE': 3.066470445582763e-05}. Best is trial 5 with value: 107.76218679738334.
# [I 2025-02-15 00:27:52,882] Trial 8 finished with value: 96.82149233797709 and parameters: {'WINDOW_SIZE': 90, 'NUM_NEURONS': 48, 'DROPOUT_RATE': 0.4, 'PATIENCE': 3, 'EPOCHS': 200, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.001750728279265666}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:35:32,594] Trial 9 finished with value: 432.76135383192354 and parameters: {'WINDOW_SIZE': 120, 'NUM_NEURONS': 112, 'DROPOUT_RATE': 0.35, 'PATIENCE': 3, 'EPOCHS': 170, 'BATCH_SIZE': 32, 'LEARNING_RATE': 1.183887387997702e-05}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:37:07,807] Trial 10 finished with value: 902.680314881342 and parameters: {'WINDOW_SIZE': 90, 'NUM_NEURONS': 32, 'DROPOUT_RATE': 0.5, 'PATIENCE': 3, 'EPOCHS': 200, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.00919368780327835}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:37:55,150] Trial 11 finished with value: 403.63526466861555 and parameters: {'WINDOW_SIZE': 50, 'NUM_NEURONS': 48, 'DROPOUT_RATE': 0.45000000000000007, 'PATIENCE': 8, 'EPOCHS': 130, 'BATCH_SIZE': 512, 'LEARNING_RATE': 0.0018835921989657947}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:43:52,554] Trial 12 finished with value: 407.0637208043466 and parameters: {'WINDOW_SIZE': 50, 'NUM_NEURONS': 64, 'DROPOUT_RATE': 0.4, 'PATIENCE': 5, 'EPOCHS': 100, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.0001033219282588458}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:44:44,659] Trial 13 finished with value: 927.21228182255 and parameters: {'WINDOW_SIZE': 50, 'NUM_NEURONS': 32, 'DROPOUT_RATE': 0.25, 'PATIENCE': 5, 'EPOCHS': 50, 'BATCH_SIZE': 256, 'LEARNING_RATE': 0.0013203068250516004}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:51:29,697] Trial 14 finished with value: 220.4790140359219 and parameters: {'WINDOW_SIZE': 100, 'NUM_NEURONS': 64, 'DROPOUT_RATE': 0.4, 'PATIENCE': 7, 'EPOCHS': 150, 'BATCH_SIZE': 128, 'LEARNING_RATE': 4.743128563846045e-05}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:52:13,898] Trial 15 finished with value: 1135.8066220448268 and parameters: {'WINDOW_SIZE': 80, 'NUM_NEURONS': 48, 'DROPOUT_RATE': 0.25, 'PATIENCE': 5, 'EPOCHS': 80, 'BATCH_SIZE': 512, 'LEARNING_RATE': 0.0011217110377399215}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:54:41,534] Trial 16 finished with value: 289.2318077457363 and parameters: {'WINDOW_SIZE': 60, 'NUM_NEURONS': 80, 'DROPOUT_RATE': 0.4, 'PATIENCE': 8, 'EPOCHS': 110, 'BATCH_SIZE': 512, 'LEARNING_RATE': 0.00013003803614782124}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:58:39,951] Trial 17 finished with value: 409.0232694529862 and parameters: {'WINDOW_SIZE': 100, 'NUM_NEURONS': 48, 'DROPOUT_RATE': 0.30000000000000004, 'PATIENCE': 4, 'EPOCHS': 200, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.00360809167721087}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 00:59:55,650] Trial 18 finished with value: 800.9807567885675 and parameters: {'WINDOW_SIZE': 40, 'NUM_NEURONS': 64, 'DROPOUT_RATE': 0.45000000000000007, 'PATIENCE': 3, 'EPOCHS': 140, 'BATCH_SIZE': 256, 'LEARNING_RATE': 0.0001859296189867249}. Best is trial 8 with value: 96.82149233797709.
# [I 2025-02-15 01:09:33,500] Trial 19 finished with value: 184.1349470612779 and parameters: {'WINDOW_SIZE': 60, 'NUM_NEURONS': 32, 'DROPOUT_RATE': 0.1, 'PATIENCE': 8, 'EPOCHS': 150, 'BATCH_SIZE': 64, 'LEARNING_RATE': 4.9763844396949556e-05}. Best is trial 8 with value: 96.82149233797709.
# Best Hyperparameters: {'WINDOW_SIZE': 90, 'NUM_NEURONS': 48, 'DROPOUT_RATE': 0.4, 'PATIENCE': 3, 'EPOCHS': 200, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.001750728279265666}
