# %% [markdown]
# ## Run locally - news data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def wrangle(path):
    # Load data
    df = pd.read_csv(path)

    # Convert 'date' column to datetime
    df['date'] = pd.to_datetime(df['Date'])

    # Sort data
    df = df.sort_values(by='date', ascending=True) 

    # Filter data for the year 2024
    df = df[df['date'].dt.year == 2024]

    # Drop columns
    df = df.drop(columns=['Date'])

    # Rename columns
    df = df.rename(columns={'CPUSAM_Close': 'CPI', 
                            '_VIXD_Close': 'VIX', 
                            '__XAU_D_Close': 'Gold', 
                            'BRT_D_Close': 'Oil', 
                            '_SPXD_Close': 'SP500'})

    # Set index
    df.set_index('date', inplace=True)

    return df

# %%
df = wrangle("/Users/alexzheng/Developer/GitHub/EC331-project/data/4.0/Macro.csv")

# %%
df
# Out:
#               SP500      CPI       Gold    VIX    Oil
# date
# 2024-01-01      NaN      NaN  2062.5901    NaN    NaN
# 2024-01-02  4742.83      NaN  2058.8767  13.20  76.24
# 2024-01-03  4704.81      NaN  2040.7760  14.04  77.18
# 2024-01-04  4688.68      NaN  2043.2600  14.13  75.79
# 2024-01-05  4697.24      NaN  2045.5000  13.35  78.31
# ...             ...      ...        ...    ...    ...
# 2024-12-25  6040.04  315.493  2634.4299  14.27  73.50
# 2024-12-26  6037.59  315.493  2634.4299  14.73  73.50
# 2024-12-27  5970.84  315.493  2620.0000  15.95  73.77
# 2024-12-30  5906.94  315.493  2605.3899  17.40  74.24
# 2024-12-31  5881.63  315.605  2623.8101  17.35  74.58
#
# [266 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# SP500     1
# CPI      22
# Gold      0
# VIX       1
# Oil       1
# dtype: int64

# %%
df.describe()
# Out:
#              SP500         CPI         Gold         VIX         Oil
# count   265.000000  244.000000   266.000000  265.000000  265.000000
# mean   5431.587019  313.550939  2389.068764   15.497019   80.537887
# std     368.500184    2.166440   222.744727    3.323150    5.416220
# min    4688.680000  308.417000  1992.130000   11.860000   70.310000
# 25%    5147.210000  312.332000  2257.795100   13.190000   75.090000
# 50%    5446.680000  314.175000  2379.890000   14.480000   81.000000
# 75%    5718.570000  315.301000  2607.174975   16.780000   84.820000
# max    6090.270000  315.664000  2786.189900   38.570000   93.120000

# %%
# Save the cleaned data
df.to_csv('/Users/alexzheng/Developer/GitHub/EC331-project/data/4.0/cleaned_Macro.csv')
