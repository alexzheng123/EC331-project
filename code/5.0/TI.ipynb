# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import talib

# %%
df = pd.read_csv("/Users/alexzheng/Developer/GitHub/EC331-project/data/Bitcoin_data_2024.csv",
                           index_col=0,
                           parse_dates=True)

# %%
# Only select data from 2024
df = df[df.index.year == 2024]

# %% [markdown]
# ## Compute the 10 important technical indicators

# %%
# Stochastics Oscillator (Fast %K and %D)
# TA-Lib STOCH returns slowk, slowd by default
df['stoch_k'], df['stoch_d'] = talib.STOCH(
    df['High'], 
    df['Low'], 
    df['Close'], 
    fastk_period=14, 
    slowk_period=3, 
    slowk_matype=0, 
    slowd_period=3, 
    slowd_matype=0
)

# %%
# Momentum Indicator
df['momentum'] = talib.MOM(df['Close'], timeperiod=10)

# %%
# MACD (Signal Line and MACD Oscillator)
df['macd'], df['macd_signal'], _ = talib.MACD(
    df['Close'], 
    fastperiod=12, 
    slowperiod=26, 
    signalperiod=9
)

# %%
# Volatility Ratio Oscillator
df['atr_short'] = talib.ATR(df['High'], df['Low'], df['Close'], timeperiod=10)
df['atr_long'] = talib.ATR(df['High'], df['Low'], df['Close'], timeperiod=20)
df['vol_ratio'] = (df['atr_short'] / df['atr_long']) * 100

# %%
# Welles Wilder’s Directional Movement Index (ADX)
df['adx'] = talib.ADX(
    df['High'], 
    df['Low'], 
    df['Close'], 
    timeperiod=14
)

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'VolumeBTC', 'VolumeUSD', 'stoch_k',
#        'stoch_d', 'momentum', 'macd', 'macd_signal', 'atr_short', 'atr_long',
#        'vol_ratio', 'adx'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                         Open     High    Low  Close  VolumeBTC     VolumeUSD  \
# date
# 2024-01-01 00:33:00  42367.0  42373.0  42365  42371   0.016585    702.728120
# 2024-01-01 00:34:00  42357.0  42357.0  42351  42351   0.019690    833.891190
# 2024-01-01 00:35:00  42359.0  42359.0  42351  42359   0.031363   1328.501505
# 2024-01-01 00:36:00  42368.0  42377.0  42356  42377   0.034081   1444.249689
# 2024-01-01 00:37:00  42395.0  42411.0  42392  42403   0.005832    247.290480
# ...                      ...      ...    ...    ...        ...           ...
# 2024-12-31 23:55:00  93476.0  93476.0  93471  93471   0.179799  16805.981112
# 2024-12-31 23:56:00  93469.0  93469.0  93469  93469   0.021400   2000.236600
# 2024-12-31 23:57:00  93462.0  93462.0  93413  93427   0.034750   3246.554616
# 2024-12-31 23:58:00  93427.0  93427.0  93427  93427   0.000000      0.000000
# 2024-12-31 23:59:00  93381.0  93381.0  93381  93381   0.005321    496.869095
#
#                        stoch_k    stoch_d  momentum       macd  macd_signal  \
# date
# 2024-01-01 00:33:00   9.166176   6.600790     -94.0   2.261327    24.403575
# 2024-01-01 00:34:00   6.163173   7.564574    -121.0  -3.058470    18.911166
# 2024-01-01 00:35:00   3.935135   6.421494    -117.0  -6.553370    13.818259
# 2024-01-01 00:36:00   9.066667   6.388325     -78.0  -7.780961     9.498415
# 2024-01-01 00:37:00  22.933333  11.978378     -33.0  -6.580002     6.282732
# ...                        ...        ...       ...        ...          ...
# 2024-12-31 23:55:00  96.651446  98.883815     155.0  19.107577    -5.403236
# 2024-12-31 23:56:00  92.462964  96.371470     146.0  21.519246    -0.018739
# 2024-12-31 23:57:00  80.506443  89.873618     108.0  19.813070     3.947623
# 2024-12-31 23:58:00  71.898475  81.622627     114.0  18.250531     6.808204
# 2024-12-31 23:59:00  55.346216  69.250378      53.0  13.148822     8.076328
#
#                      atr_short   atr_long   vol_ratio        adx
# date
# 2024-01-01 00:33:00  19.252096  18.831203  102.235086  47.478318
# 2024-01-01 00:34:00  19.326887  18.889643  102.314729  44.942988
# 2024-01-01 00:35:00  18.194198  18.345160   99.177099  42.503637
# 2024-01-01 00:36:00  18.474778  18.477902   99.983092  39.498642
# 2024-01-01 00:37:00  20.027300  19.254007  104.016271  37.792666
# ...                        ...        ...         ...        ...
# 2024-12-31 23:55:00  23.668514  25.339229   93.406607  23.141107
# 2024-12-31 23:56:00  21.501662  24.172267   88.951781  22.308489
# 2024-12-31 23:57:00  24.951496  25.763654   96.847661  21.254018
# 2024-12-31 23:58:00  22.456346  24.475471   91.750415  20.274865
# 2024-12-31 23:59:00  24.810712  25.551698   97.100053  20.289356
#
# [509331 rows x 15 columns]

# %%
df.to_csv("/Users/alexzheng/Developer/GitHub/EC331-project/data/5.0/Bitcoin_data.csv")
