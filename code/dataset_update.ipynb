# %%
import pandas as pd

# %%
def wrangle(path, col_1, col_2):

    # Import data
    df = pd.read_csv(path)

    # Datetime 
    df[col_1] = pd.to_datetime(df[col_1])

    # Rename the column to date
    df.rename(columns={col_1: 'Date'}, inplace=True)

    # Replace missing values
    df[col_2] = df[col_2].replace('.', pd.NA)
    # Convert to numeric, coercing errors to NaN
    df[col_2] = pd.to_numeric(df[col_2], errors='coerce')

    # Only select data between 2000-01-01 and 2024-12-31
    df = df[(df['Date'] >= '2000-01-01') & (df['Date'] <= '2024-12-31')]

    df = df.set_index('Date')

    return df

# %%
vix1 = wrangle("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/old_data/CBOE_Volatility_Index.csv",
               "DATE",
               "VIXCLS")
print(vix1.tail())
vix1.count()
# Out:
#             VIXCLS
# Date
# 2024-11-14   14.31
# 2024-11-15   16.14
# 2024-11-18   15.58
# 2024-11-19   16.35
# 2024-11-20   17.16
# VIXCLS    6281
# dtype: int64

# %%
vix2 = wrangle("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/old_data/VIX_new.csv",
               "observation_date",
               "VIXCLS")
print(vix2.head())
vix2.count()
# Out:
#             VIXCLS
# Date
# 2024-11-21   16.87
# 2024-11-22   15.24
# 2024-11-25   14.60
# 2024-11-26   14.10
# 2024-11-27   14.10
# VIXCLS    28
# dtype: int64

# %%
JP_IR1 = wrangle("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/old_data/Japan_Government_Debt_10_Year.csv",
                 "Pricing Date",
                 "Japan Government Debt - 10 Year")
print(JP_IR1.tail())
JP_IR1.count()
# Out:
#             Japan Government Debt - 10 Year
# Date
# 2024-11-13                            1.039
# 2024-11-14                            1.054
# 2024-11-15                            1.070
# 2024-11-18                            1.065
# 2024-11-19                            1.064
# Japan Government Debt - 10 Year    7807
# dtype: int64

# %%
JP_IR2 = wrangle("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/old_data/JP_IR_new.csv",
                 "Pricing Date",
                 "Japan Government Debt - 10 Year")
print(JP_IR2.head())
JP_IR2.count()
# Out:
#             Japan Government Debt - 10 Year
# Date
# 2024-11-20                            1.064
# 2024-11-21                            1.110
# 2024-11-22                            1.102
# 2024-11-26                            1.080
# 2024-11-27                            1.094
# Japan Government Debt - 10 Year    28
# dtype: int64

# %%
US_IR1 = wrangle("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/old_data/Market_Yield_US_Treasury_Securities_10_Year_Constant_Maturity_Investment_Basis.csv",
                 "DATE",
                 "DGS10")
print(US_IR1.tail())
US_IR1.count()
# Out:
#             DGS10
# Date
# 2024-11-12   4.43
# 2024-11-13   4.44
# 2024-11-14   4.43
# 2024-11-15   4.43
# 2024-11-18   4.42
# DGS10    6224
# dtype: int64

# %%
US_IR2 = wrangle("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/old_data/US_IR_new.csv",
                 "observation_date",
                 "DGS10")
print(US_IR2.head())
US_IR2.count()
# Out:
#             DGS10
# Date
# 2024-11-19   4.39
# 2024-11-20   4.41
# 2024-11-21   4.43
# 2024-11-22   4.41
# 2024-11-25   4.27
# DGS10    29
# dtype: int64

# %%
ER1 = wrangle("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/old_data/Japanese_Yen_to_US_Dollar_Spot_Exchange_Rate.csv",
              "DATE",
              "DEXJPUS")
print(ER1.tail())
ER1.count()
# Out:
#             DEXJPUS
# Date
# 2024-11-11      NaN
# 2024-11-12   154.73
# 2024-11-13   155.28
# 2024-11-14   155.96
# 2024-11-15   154.59
# DEXJPUS    6238
# dtype: int64

# %%
ER2 = wrangle("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/old_data/ER_new.csv",
              "observation_date",
              "DEXJPUS")
print(ER2.head())
ER2.count()
# Out:
#             DEXJPUS
# Date
# 2024-11-18   154.78
# 2024-11-19   154.34
# 2024-11-20   155.38
# 2024-11-21   154.66
# 2024-11-22   154.73
# DEXJPUS    30
# dtype: int64

# %%
vix = pd.concat([vix1,vix2])
JP_IR = pd.concat([JP_IR1, JP_IR2])
US_IR = pd.concat([US_IR1, US_IR2])
ER = pd.concat([ER1, ER2])

# %%
vix.count()
# Out:
# VIXCLS    6309
# dtype: int64

# %%
JP_IR.count()
# Out:
# Japan Government Debt - 10 Year    7835
# dtype: int64

# %%
US_IR.count()
# Out:
# DGS10    6253
# dtype: int64

# %%
ER.count()
# Out:
# DEXJPUS    6268
# dtype: int64

# %%
vix.to_csv("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/vix_updated.csv", index=True)
JP_IR.to_csv("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/JP_IR_updated.csv", index=True)
US_IR.to_csv("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/US_IR_updated.csv", index=True)
ER.to_csv("/Users/alexzheng/Developer/GitHub/Forecasting-Yen-Carry-Trade-Risk-Using-an-LLM/data/ER_updated.csv", index=True)
