# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
def wrangle(path):
    # Load data
    df = pd.read_csv(path, skiprows=1)

    # Convert first column to datetime 
    df['date'] = pd.to_datetime(df['unix'], unit = "s")
    df = df.sort_values(by='date', ascending=True)

    # Set index
    df.set_index('date', inplace=True)

    # Drop columns
    df = df.drop(columns=['unix', 'symbol'])

    return df

# %%
df = wrangle("/Users/alexzheng/Developer/GitHub/EC331-project/data/3.0/Bitstamp_BTCUSD_2021_minute.csv")

# %%
df.count()
# Out:
# open          640064
# high          640064
# low           640064
# close         640064
# Volume BTC    640064
# Volume USD    640064
# dtype: int64

# %%
df.head()
# Out:
#                          open      high       low     close  Volume BTC  \
# date
# 2021-01-01 00:01:00  29007.31  29086.90  29007.31  29083.47   14.561951
# 2021-01-01 00:02:00  29069.80  29073.02  29028.14  29035.89    3.030301
# 2021-01-01 00:03:00  29037.68  29069.39  29019.00  29048.13    2.189621
# 2021-01-01 00:04:00  29048.13  29057.73  29035.61  29045.19    1.446538
# 2021-01-01 00:05:00  29021.86  29023.38  28982.33  28999.50    1.062360
#
#                         Volume USD
# date
# 2021-01-01 00:01:00  423512.060397
# 2021-01-01 00:02:00   87987.499279
# 2021-01-01 00:03:00   63604.382387
# 2021-01-01 00:04:00   42014.959434
# 2021-01-01 00:05:00   30807.899250

# %%
df.tail()
# Out:
#                          open      high       low     close  Volume BTC  \
# date
# 2022-03-21 11:40:00  41245.56  41274.15  41243.31  41274.15    1.001110
# 2022-03-21 11:41:00  41274.15  41274.15  41273.33  41274.15    0.007057
# 2022-03-21 11:42:00  41264.06  41282.03  41260.81  41282.03    0.312523
# 2022-03-21 11:43:00  41293.07  41296.17  41293.07  41293.53    0.484014
# 2022-03-21 11:44:00  41292.70  41292.70  41271.28  41282.43    0.010763
#
#                        Volume USD
# date
# 2022-03-21 11:40:00  41319.964306
# 2022-03-21 11:41:00    291.290250
# 2022-03-21 11:42:00  12901.578908
# 2022-03-21 11:43:00  19986.628460
# 2022-03-21 11:44:00    444.340133

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 640064 entries, 2021-01-01 00:01:00 to 2022-03-21 11:44:00
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   open        640064 non-null  float64
#  1   high        640064 non-null  float64
#  2   low         640064 non-null  float64
#  3   close       640064 non-null  float64
#  4   Volume BTC  640064 non-null  float64
#  5   Volume USD  640064 non-null  float64
# dtypes: float64(6)
# memory usage: 34.2 MB
# None
#                 open           high            low          close  \
# count  640064.000000  640064.000000  640064.000000  640064.000000
# mean    46204.898712   46231.925033   46177.217291   46205.214882
# std      9329.376674    9330.475634    9328.230610    9329.484851
# min     28093.810000   28397.520000   27734.000000   28073.030000
# 25%     38360.210000   38384.365000   38332.300000   38361.345000
# ...

# %%
# Plot the 'close' prices
df['close'].plot(figsize=(12, 6))
plt.xlabel('Date')
plt.ylabel('Values (USD)');

# %%
df.head()
# Out:
#                          open      high       low     close  Volume BTC  \
# date
# 2021-01-01 00:01:00  29007.31  29086.90  29007.31  29083.47   14.561951
# 2021-01-01 00:02:00  29069.80  29073.02  29028.14  29035.89    3.030301
# 2021-01-01 00:03:00  29037.68  29069.39  29019.00  29048.13    2.189621
# 2021-01-01 00:04:00  29048.13  29057.73  29035.61  29045.19    1.446538
# 2021-01-01 00:05:00  29021.86  29023.38  28982.33  28999.50    1.062360
#
#                         Volume USD
# date
# 2021-01-01 00:01:00  423512.060397
# 2021-01-01 00:02:00   87987.499279
# 2021-01-01 00:03:00   63604.382387
# 2021-01-01 00:04:00   42014.959434
# 2021-01-01 00:05:00   30807.899250

# %%
df.to_csv("/Users/alexzheng/Developer/GitHub/EC331-project/data/3.0/Bitcoin_data.csv")
