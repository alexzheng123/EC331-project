# %% [markdown]
# # Robustness Checks (0.5/0.3/0.2 split)

# %%
# !pip install vmdpy optuna --quiet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from vmdpy import VMD
import optuna

# Set random seeds for reproducibility
import random
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Ensure plot qualities
plt.rcParams['figure.figsize'] = (12,6)
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300  # Adjust DPI for high-resolution figures

# %%
# Global Variables
TRAIN_RATIO = 0.5
VAL_RATIO = 0.3
TEST_RATIO = 0.2

K = 8 # Number of IMFs

WINDOW_SIZE = 60
# Default values; these will be tuned via optuna
NUM_NEURONS = 128
DROPOUT_RATE = 0.3
PATIENCE = 10
EPOCHS = 100
BATCH_SIZE = 256
LEARNING_RATE = 0.001

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Ensure TensorFlow is using GPU
device_name = tf.test.gpu_device_name()
if device_name:
    print(f"GPU Detected: {device_name}")
else:
    print("No GPU found. Training may be slow.")
# Out:
# GPU Detected: /device:GPU:0

# %%
# Load the data
data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/EMH/data/Bitcoin_data_2024_w_TI_n_Macro.csv",
                   index_col=0, parse_dates=True)
data = data[['Returns%']]

# Ensure the data is univariate
if data.shape[1] != 1:
    raise ValueError("Data must be univariate with only 'Returns%' column.")

# %%
data.isna().sum()
# Out:
# Returns%    0
# dtype: int64

# %%
# Split the data
n = len(data)
train_end = int(n * TRAIN_RATIO)
val_end = train_end + int(n * VAL_RATIO)

train_data = data.iloc[:train_end]
val_data   = data.iloc[train_end:val_end]
test_data  = data.iloc[val_end:]

print("Train shape:", train_data.shape)
print("Validation shape:", val_data.shape)
print("Test shape:", test_data.shape)
# Out:
# Train shape: (254707, 1)
# Validation shape: (152824, 1)
# Test shape: (101883, 1)

# %%
# Modified VMD application with proper boundary handling
def safe_vmd_decomposition(main_data, prev_data, window_size):
    """Apply VMD with boundary handling to prevent leakage"""
    extended_data = np.concatenate([prev_data[-window_size:], main_data])
    u, _, _ = VMD(extended_data, alpha=2000, tau=0, K=8, DC=0, init=1, tol=1e-7)
    return u[:, window_size:]  # Trim overlapping portion

# Apply VMD to training data (no previous data)
train_return = train_data['Returns%'].values
u_train, _, _ = VMD(train_return, alpha=2000, tau=0, K=8, DC=0, init=1, tol=1e-7)
vmd_train = pd.DataFrame(u_train.T, columns=[f'IMF_{i}' for i in range(8)], index=train_data.index[:u_train.T.shape[0]])

# %%
# Apply VMD to validation data using training boundary
val_return = val_data['Returns%'].values
u_val = safe_vmd_decomposition(val_return, train_return, WINDOW_SIZE)
vmd_val = pd.DataFrame(u_val.T, columns=[f'IMF_{i}' for i in range(8)], index=val_data.index)

# %%
# Apply VMD to test data using validation boundary
test_return = test_data['Returns%'].values
u_test = safe_vmd_decomposition(test_return, val_return, WINDOW_SIZE)
vmd_test = pd.DataFrame(u_test.T, columns=[f'IMF_{i}' for i in range(8)], index=test_data.index[:u_test.T.shape[0]])

# %%
# Initialize scalers using ONLY training data
scaler_imfs = {}
for i in range(8):
    scaler = MinMaxScaler()
    scaler.fit(vmd_train[[f'IMF_{i}']])  # Train on training IMFs only
    scaler_imfs[f'IMF_{i}'] = scaler

# Scale all sets using training scalers
def safe_scale(df, scaler_dict):
    scaled_df = df.copy()
    for imf in scaler_dict:
        scaled_df[imf] = scaler_dict[imf].transform(df[[imf]])
    return scaled_df

vmd_train = safe_scale(vmd_train, scaler_imfs)
vmd_val = safe_scale(vmd_val, scaler_imfs)
vmd_test = safe_scale(vmd_test, scaler_imfs)

# %%
# Plot VMD decomposition for the training period
fig, axs = plt.subplots(K+1, 1, figsize=(12, 8))
axs[0].plot(train_data['Returns%'].values, label="Original Returns")
# axs[0].set_title("Original Returns")
for i in range(K):
    axs[i+1].plot(vmd_train[f'IMF_{i}'], label=f"IMF_{i}")
    axs[i+1].legend()
plt.tight_layout()
plt.show()

# %%
# Updated sequence creation with temporal safeguards
def create_leakproof_sequences(df, window_size):
    """Create sequences ensuring no future data contamination"""
    X, y = [], []
    for i in range(len(df) - window_size):
        X.append(df.iloc[i:i+window_size].values)
        y.append(df.iloc[i+window_size].values)
    return np.array(X), np.array(y)

# Create sequences for each IMF set
X_train, y_train = create_leakproof_sequences(vmd_train, WINDOW_SIZE)
X_val, y_val = create_leakproof_sequences(vmd_val, WINDOW_SIZE)
X_test, y_test = create_leakproof_sequences(vmd_test, WINDOW_SIZE)

# Reshape for GRU input (samples, timesteps, features)
X_train = X_train.transpose(0, 2, 1)
X_val = X_val.transpose(0, 2, 1)
X_test = X_test.transpose(0, 2, 1)

print("X_train shape:", X_train.shape)  # Expect (samples, K, WINDOW_SIZE)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (254646, 8, 60)
# y_train shape: (254646, 8)

# %%
# Define the Attention-GRU Model with Hyperparameter Arguments
def build_attention_gru_model(input_shape, num_neurons, dropout_rate, learning_rate):
    """
    Build an Attention-GRU model with hyperparameters.
    input_shape: (timesteps, features) → here (WINDOW_SIZE, 1)
    """
    print(f"Building model with input shape: {input_shape}, num_neurons: {num_neurons}, dropout_rate: {dropout_rate}, learning_rate: {learning_rate}")
    inputs = Input(shape=input_shape)
    x = GRU(num_neurons, return_sequences=True)(inputs)
    # Using Keras's built-in attention layer (query=key=x)
    x = tf.keras.layers.Attention()([x, x])
    x = Dropout(dropout_rate)(x)
    x = Flatten()(x)
    output = Dense(1)(x)
    model = Model(inputs, output)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error')
    return model

# %%
# Hyperparameter Tuning with Optuna
def objective(trial):
    # Suggest hyperparameters
    num_neurons = trial.suggest_int("num_neurons", 64, 256, step=32)
    dropout_rate = trial.suggest_float("dropout_rate", 0.1, 0.5)
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-2)

    # Build model with suggested hyperparameters
    model = build_attention_gru_model((WINDOW_SIZE, 1), num_neurons, dropout_rate, learning_rate)

    # Use early stopping to avoid overfitting during tuning
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, mode='min')

    # For tuning, we use the IMF_0 data (reshape to add channel dimension)
    history = model.fit(
        X_train[:, 0, :].reshape(-1, WINDOW_SIZE, 1),
        y_train[:, 0],
        validation_data=(X_val[:, 0, :].reshape(-1, WINDOW_SIZE, 1), y_val[:, 0]),
        epochs=20,  # Fewer epochs for faster tuning
        batch_size=BATCH_SIZE,
        callbacks=[early_stop],
        verbose=0
    )

    # Return the best validation loss achieved during tuning
    val_loss = min(history.history['val_loss'])
    return val_loss

# Create and run the study
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)
best_params = study.best_params
print("Best hyperparameters found:", best_params)
# Out:
# [I 2025-04-15 19:15:29,739] A new study created in memory with name: no-name-47027a8d-087c-40b8-b010-3d2fd77f042a
# Building model with input shape: (60, 1), num_neurons: 224, dropout_rate: 0.28503148109402743, learning_rate: 0.0033556786869377232
# [I 2025-04-15 19:16:38,879] Trial 0 finished with value: 0.00031499608303420246 and parameters: {'num_neurons': 224, 'dropout_rate': 0.28503148109402743, 'learning_rate': 0.0033556786869377232}. Best is trial 0 with value: 0.00031499608303420246.
# Building model with input shape: (60, 1), num_neurons: 64, dropout_rate: 0.2979765299025715, learning_rate: 0.0004977744688582594
# [I 2025-04-15 19:19:01,485] Trial 1 finished with value: 1.4672003999294247e-05 and parameters: {'num_neurons': 64, 'dropout_rate': 0.2979765299025715, 'learning_rate': 0.0004977744688582594}. Best is trial 1 with value: 1.4672003999294247e-05.
# Building model with input shape: (60, 1), num_neurons: 256, dropout_rate: 0.16435233639890384, learning_rate: 0.0007918540090421937
# [I 2025-04-15 19:21:10,616] Trial 2 finished with value: 2.5865883799269795e-05 and parameters: {'num_neurons': 256, 'dropout_rate': 0.16435233639890384, 'learning_rate': 0.0007918540090421937}. Best is trial 1 with value: 1.4672003999294247e-05.
# Building model with input shape: (60, 1), num_neurons: 64, dropout_rate: 0.3418921211621847, learning_rate: 0.001326456895892553
# [I 2025-04-15 19:23:32,497] Trial 3 finished with value: 1.2029822755721398e-05 and parameters: {'num_neurons': 64, 'dropout_rate': 0.3418921211621847, 'learning_rate': 0.001326456895892553}. Best is trial 3 with value: 1.2029822755721398e-05.
# Building model with input shape: (60, 1), num_neurons: 96, dropout_rate: 0.1281217747074726, learning_rate: 0.008738831544498274
# [I 2025-04-15 19:24:43,866] Trial 4 finished with value: 0.00011546994210220873 and parameters: {'num_neurons': 96, 'dropout_rate': 0.1281217747074726, 'learning_rate': 0.008738831544498274}. Best is trial 3 with value: 1.2029822755721398e-05.
# Building model with input shape: (60, 1), num_neurons: 224, dropout_rate: 0.24608895234548359, learning_rate: 0.0011046849704013247
# [I 2025-04-15 19:26:43,048] Trial 5 finished with value: 1.656663152971305e-05 and parameters: {'num_neurons': 224, 'dropout_rate': 0.24608895234548359, 'learning_rate': 0.0011046849704013247}. Best is trial 3 with value: 1.2029822755721398e-05.
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# [I 2025-04-15 19:29:01,998] Trial 6 finished with value: 1.0312613085261546e-05 and parameters: {'num_neurons': 128, 'dropout_rate': 0.14036310267029162, 'learning_rate': 0.0007262463191695631}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 64, dropout_rate: 0.44293905563170033, learning_rate: 0.0010689172170826038
# [I 2025-04-15 19:30:34,455] Trial 7 finished with value: 3.3821313991211355e-05 and parameters: {'num_neurons': 64, 'dropout_rate': 0.44293905563170033, 'learning_rate': 0.0010689172170826038}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 96, dropout_rate: 0.18046030589044848, learning_rate: 0.0001982471209541014
# [I 2025-04-15 19:32:53,052] Trial 8 finished with value: 2.6903000616584904e-05 and parameters: {'num_neurons': 96, 'dropout_rate': 0.18046030589044848, 'learning_rate': 0.0001982471209541014}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 64, dropout_rate: 0.35803792740544704, learning_rate: 0.004073609557770377
# [I 2025-04-15 19:34:11,175] Trial 9 finished with value: 3.167956674587913e-05 and parameters: {'num_neurons': 64, 'dropout_rate': 0.35803792740544704, 'learning_rate': 0.004073609557770377}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 160, dropout_rate: 0.49402135886509535, learning_rate: 0.00010173503037207711
# [I 2025-04-15 19:36:31,949] Trial 10 finished with value: 4.710211214842275e-05 and parameters: {'num_neurons': 160, 'dropout_rate': 0.49402135886509535, 'learning_rate': 0.00010173503037207711}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.37648923438241905, learning_rate: 0.002077684984259336
# [I 2025-04-15 19:37:55,825] Trial 11 finished with value: 2.7645424779620953e-05 and parameters: {'num_neurons': 128, 'dropout_rate': 0.37648923438241905, 'learning_rate': 0.002077684984259336}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 160, dropout_rate: 0.21537468656478356, learning_rate: 0.0003113493057462868
# [I 2025-04-15 19:39:42,769] Trial 12 finished with value: 4.677896504290402e-05 and parameters: {'num_neurons': 160, 'dropout_rate': 0.21537468656478356, 'learning_rate': 0.0003113493057462868}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.10367639078068755, learning_rate: 0.0016617305560960715
# [I 2025-04-15 19:41:15,719] Trial 13 finished with value: 2.1315732738003135e-05 and parameters: {'num_neurons': 128, 'dropout_rate': 0.10367639078068755, 'learning_rate': 0.0016617305560960715}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 160, dropout_rate: 0.3694210563384916, learning_rate: 0.0004479495315858988
# [I 2025-04-15 19:43:30,514] Trial 14 finished with value: 3.067020952585153e-05 and parameters: {'num_neurons': 160, 'dropout_rate': 0.3694210563384916, 'learning_rate': 0.0004479495315858988}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 96, dropout_rate: 0.32589954238874247, learning_rate: 0.0006443805929865912
# [I 2025-04-15 19:45:51,508] Trial 15 finished with value: 1.4428005670197308e-05 and parameters: {'num_neurons': 96, 'dropout_rate': 0.32589954238874247, 'learning_rate': 0.0006443805929865912}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.24756597971344796, learning_rate: 0.002139978878181934
# [I 2025-04-15 19:46:55,742] Trial 16 finished with value: 6.768288585590199e-05 and parameters: {'num_neurons': 128, 'dropout_rate': 0.24756597971344796, 'learning_rate': 0.002139978878181934}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 192, dropout_rate: 0.4197920236692202, learning_rate: 0.0002642252069871491
# [I 2025-04-15 19:49:31,147] Trial 17 finished with value: 1.553760921524372e-05 and parameters: {'num_neurons': 192, 'dropout_rate': 0.4197920236692202, 'learning_rate': 0.0002642252069871491}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 96, dropout_rate: 0.2575869156023563, learning_rate: 0.005573380154661957
# [I 2025-04-15 19:51:02,744] Trial 18 finished with value: 2.665993270056788e-05 and parameters: {'num_neurons': 96, 'dropout_rate': 0.2575869156023563, 'learning_rate': 0.005573380154661957}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 64, dropout_rate: 0.20535694336706295, learning_rate: 0.001433952362022712
# [I 2025-04-15 19:52:49,330] Trial 19 finished with value: 1.9548411728464998e-05 and parameters: {'num_neurons': 64, 'dropout_rate': 0.20535694336706295, 'learning_rate': 0.001433952362022712}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.4193240525995821, learning_rate: 0.002886645609192582
# [I 2025-04-15 19:53:53,293] Trial 20 finished with value: 5.362554657040164e-05 and parameters: {'num_neurons': 128, 'dropout_rate': 0.4193240525995821, 'learning_rate': 0.002886645609192582}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 96, dropout_rate: 0.3195289025495827, learning_rate: 0.0007267486297982185
# [I 2025-04-15 19:56:05,142] Trial 21 finished with value: 1.3849058632331435e-05 and parameters: {'num_neurons': 96, 'dropout_rate': 0.3195289025495827, 'learning_rate': 0.0007267486297982185}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 96, dropout_rate: 0.32082327507563557, learning_rate: 0.0007484826422683008
# [I 2025-04-15 19:58:24,958] Trial 22 finished with value: 1.1599174285947811e-05 and parameters: {'num_neurons': 96, 'dropout_rate': 0.32082327507563557, 'learning_rate': 0.0007484826422683008}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.3380709044924012, learning_rate: 0.000453400452572321
# [I 2025-04-15 20:00:43,917] Trial 23 finished with value: 1.1716577319020871e-05 and parameters: {'num_neurons': 128, 'dropout_rate': 0.3380709044924012, 'learning_rate': 0.000453400452572321}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 160, dropout_rate: 0.28152057948249687, learning_rate: 0.00042778732785183536
# [I 2025-04-15 20:03:05,001] Trial 24 finished with value: 1.293304012506269e-05 and parameters: {'num_neurons': 160, 'dropout_rate': 0.28152057948249687, 'learning_rate': 0.00042778732785183536}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.38905745352895993, learning_rate: 0.0001811831814485407
# [I 2025-04-15 20:05:24,384] Trial 25 finished with value: 3.020075018866919e-05 and parameters: {'num_neurons': 128, 'dropout_rate': 0.38905745352895993, 'learning_rate': 0.0001811831814485407}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 192, dropout_rate: 0.14271624150904721, learning_rate: 0.0003186444692608882
# [I 2025-04-15 20:07:59,582] Trial 26 finished with value: 1.840978984546382e-05 and parameters: {'num_neurons': 192, 'dropout_rate': 0.14271624150904721, 'learning_rate': 0.0003186444692608882}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.32375410122216347, learning_rate: 0.0006246337547623653
# [I 2025-04-15 20:10:18,259] Trial 27 finished with value: 1.0404116437712219e-05 and parameters: {'num_neurons': 128, 'dropout_rate': 0.32375410122216347, 'learning_rate': 0.0006246337547623653}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 192, dropout_rate: 0.3058760482192701, learning_rate: 0.0008398468469744146
# [I 2025-04-15 20:12:07,175] Trial 28 finished with value: 2.391802081547212e-05 and parameters: {'num_neurons': 192, 'dropout_rate': 0.3058760482192701, 'learning_rate': 0.0008398468469744146}. Best is trial 6 with value: 1.0312613085261546e-05.
# Building model with input shape: (60, 1), num_neurons: 96, dropout_rate: 0.2722483353303946, learning_rate: 0.0005976123331962933
# [I 2025-04-15 20:13:38,597] Trial 29 finished with value: 7.025215745670721e-05 and parameters: {'num_neurons': 96, 'dropout_rate': 0.2722483353303946, 'learning_rate': 0.0005976123331962933}. Best is trial 6 with value: 1.0312613085261546e-05.
# Best hyperparameters found: {'num_neurons': 128, 'dropout_rate': 0.14036310267029162, 'learning_rate': 0.0007262463191695631}

# %%
# Best hyperparameters found: {'num_neurons': 128, 'dropout_rate': 0.14036310267029162, 'learning_rate': 0.0007262463191695631}

# %%
# Model Training using the Best Hyperparameters
def train_imf_model(imf_index, X_train, y_train, X_val, y_val, num_neurons, dropout_rate, learning_rate):
    model = build_attention_gru_model((WINDOW_SIZE, 1), num_neurons, dropout_rate, learning_rate)
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=PATIENCE,
        restore_best_weights=True,
        mode='min'
    )

    history = model.fit(
        X_train[:, imf_index, :].reshape(-1, WINDOW_SIZE, 1),
        y_train[:, imf_index],
        validation_data=(X_val[:, imf_index, :].reshape(-1, WINDOW_SIZE, 1), y_val[:, imf_index]),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[early_stop],
        verbose=1
    )
    return model, history

# Train models for each IMF using the best hyperparameters from optuna
models = []
for i in range(8):
    print(f"\nTraining model for IMF_{i}...")
    model, _ = train_imf_model(i, X_train, y_train, X_val, y_val,
                               num_neurons=best_params['num_neurons'],
                               dropout_rate=best_params['dropout_rate'],
                               learning_rate=best_params['learning_rate'])
    models.append(model)
# Out:
# Training model for IMF_0...
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# Epoch 1/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0074 - val_loss: 0.0011
# Epoch 2/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 3/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0011 - val_loss: 8.9401e-04
# Epoch 4/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.1875e-04 - val_loss: 5.7699e-04
# Epoch 5/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.3629e-04 - val_loss: 1.0889e-04
# Epoch 6/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1241e-04 - val_loss: 1.6390e-04
# Epoch 7/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.0135e-05 - val_loss: 1.2313e-04
# Epoch 8/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.4854e-05 - val_loss: 9.6283e-05
# Epoch 9/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.6571e-05 - val_loss: 8.2161e-05
# Epoch 10/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.0596e-05 - val_loss: 3.0247e-05
# Epoch 11/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.6189e-05 - val_loss: 2.4731e-05
# Epoch 12/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.7672e-05 - val_loss: 5.4291e-05
# Epoch 13/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.3421e-05 - val_loss: 4.3576e-05
# Epoch 14/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.0694e-05 - val_loss: 1.8435e-05
# Epoch 15/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.8462e-05 - val_loss: 2.8053e-05
# Epoch 16/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.8134e-05 - val_loss: 2.4266e-05
# Epoch 17/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.7343e-05 - val_loss: 1.0390e-05
# Epoch 18/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.2937e-05 - val_loss: 1.2659e-05
# Epoch 19/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.2424e-05 - val_loss: 1.8849e-05
# Epoch 20/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1284e-05 - val_loss: 1.1575e-05
# Epoch 21/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1419e-05 - val_loss: 8.5746e-06
# Epoch 22/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9624e-05 - val_loss: 7.1818e-06
# Epoch 23/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9951e-05 - val_loss: 8.4525e-06
# Epoch 24/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.8094e-05 - val_loss: 6.9617e-06
# Epoch 25/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.8733e-05 - val_loss: 8.2977e-06
# Epoch 26/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7715e-05 - val_loss: 9.1992e-06
# Epoch 27/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7749e-05 - val_loss: 8.5635e-06
# Epoch 28/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.2412e-05 - val_loss: 7.3598e-06
# Epoch 29/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7236e-05 - val_loss: 2.8295e-05
# Epoch 30/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7864e-05 - val_loss: 6.2313e-06
# Epoch 31/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5748e-05 - val_loss: 1.7046e-05
# Epoch 32/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6330e-05 - val_loss: 8.0532e-06
# Epoch 33/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5778e-05 - val_loss: 8.3934e-06
# Epoch 34/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5193e-05 - val_loss: 8.5679e-06
# Epoch 35/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4795e-05 - val_loss: 6.0643e-06
# Epoch 36/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5043e-05 - val_loss: 5.5512e-06
# Epoch 37/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3658e-05 - val_loss: 5.1178e-06
# Epoch 38/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4481e-05 - val_loss: 6.9375e-06
# Epoch 39/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4826e-05 - val_loss: 1.4633e-05
# Epoch 40/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4620e-05 - val_loss: 5.3552e-06
# Epoch 41/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3240e-05 - val_loss: 5.2228e-06
# Epoch 42/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4081e-05 - val_loss: 5.4661e-06
# Epoch 43/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3043e-05 - val_loss: 6.9633e-06
# Epoch 44/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2512e-05 - val_loss: 1.4849e-05
# Epoch 45/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3636e-05 - val_loss: 1.0861e-05
# Epoch 46/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2539e-05 - val_loss: 1.0772e-05
# Epoch 47/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1880e-05 - val_loss: 4.4361e-06
# Epoch 48/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1855e-05 - val_loss: 4.4695e-06
# Epoch 49/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1335e-05 - val_loss: 8.6025e-06
# Epoch 50/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1155e-05 - val_loss: 1.0302e-05
# Epoch 51/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1859e-05 - val_loss: 1.0387e-05
# Epoch 52/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.0661e-05 - val_loss: 8.1138e-06
# Epoch 53/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1250e-05 - val_loss: 6.7396e-06
# Epoch 54/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1273e-05 - val_loss: 5.0135e-06
# Epoch 55/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.0942e-05 - val_loss: 1.5181e-05
# Epoch 56/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.0560e-05 - val_loss: 5.3787e-06
# Epoch 57/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1039e-05 - val_loss: 6.6820e-06
#
# Training model for IMF_1...
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# Epoch 1/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0040 - val_loss: 7.6018e-04
# Epoch 2/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.5804e-04 - val_loss: 8.2832e-04
# Epoch 3/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.2605e-04 - val_loss: 7.5399e-04
# Epoch 4/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.0519e-04 - val_loss: 7.4663e-04
# Epoch 5/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.8694e-04 - val_loss: 7.3606e-04
# Epoch 6/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.0556e-04 - val_loss: 1.2102e-04
# Epoch 7/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.1058 - val_loss: 6.1018e-04
# Epoch 8/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0026 - val_loss: 4.6878e-04
# Epoch 9/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0013 - val_loss: 4.1249e-04
# Epoch 10/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.0697e-04 - val_loss: 3.7539e-04
# Epoch 11/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.9620e-04 - val_loss: 3.4030e-04
# Epoch 12/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.0311e-04 - val_loss: 3.0576e-04
# Epoch 13/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.3991e-04 - val_loss: 2.6770e-04
# Epoch 14/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.8420e-04 - val_loss: 2.2596e-04
# Epoch 15/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.2986e-04 - val_loss: 1.8720e-04
# Epoch 16/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.8668e-04 - val_loss: 1.4137e-04
#
# Training model for IMF_2...
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# Epoch 1/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0052 - val_loss: 3.8579e-04
# Epoch 2/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.6808e-04 - val_loss: 4.0647e-04
# Epoch 3/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.3396e-04 - val_loss: 3.8648e-04
# Epoch 4/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.2717e-04 - val_loss: 3.8515e-04
# Epoch 5/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.1940e-04 - val_loss: 4.1123e-04
# Epoch 6/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.1314e-04 - val_loss: 4.2221e-04
# Epoch 7/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.0856e-04 - val_loss: 4.2289e-04
# Epoch 8/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.0209e-04 - val_loss: 3.9845e-04
# Epoch 9/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.7848e-04 - val_loss: 1.2293e-04
# Epoch 10/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.7561e-05 - val_loss: 3.0008e-05
# Epoch 11/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.6508e-05 - val_loss: 2.1327e-05
# Epoch 12/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.9534e-05 - val_loss: 2.4997e-05
# Epoch 13/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.8976e-05 - val_loss: 2.6793e-05
# Epoch 14/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.6211e-05 - val_loss: 2.5931e-05
# Epoch 15/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.2814e-04 - val_loss: 2.0554e-04
# Epoch 16/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5928e-04 - val_loss: 3.8814e-05
# Epoch 17/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.8110e-05 - val_loss: 2.2090e-05
# Epoch 18/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.5988e-05 - val_loss: 1.4247e-05
# Epoch 19/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1055e-05 - val_loss: 1.2488e-05
# Epoch 20/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0343e-05 - val_loss: 1.0940e-05
# Epoch 21/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9646e-05 - val_loss: 1.2089e-05
# Epoch 22/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1821e-05 - val_loss: 1.1238e-05
# Epoch 23/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9358e-05 - val_loss: 1.3735e-05
# Epoch 24/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0014 - val_loss: 2.1465e-04
# Epoch 25/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.4845e-04 - val_loss: 1.8147e-04
# Epoch 26/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.8781e-04 - val_loss: 1.0294e-04
# Epoch 27/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.2928e-05 - val_loss: 3.4449e-05
# Epoch 28/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.6906e-05 - val_loss: 2.7676e-05
# Epoch 29/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.0359e-05 - val_loss: 1.7478e-05
# Epoch 30/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.2228e-05 - val_loss: 2.2600e-05
#
# Training model for IMF_3...
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# Epoch 1/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0036 - val_loss: 5.8376e-04
# Epoch 2/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.4802e-04 - val_loss: 5.8277e-04
# Epoch 3/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.2352e-04 - val_loss: 5.9321e-04
# Epoch 4/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.1464e-04 - val_loss: 5.8105e-04
# Epoch 5/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.1359e-04 - val_loss: 5.7979e-04
# Epoch 6/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.0724e-04 - val_loss: 5.8547e-04
# Epoch 7/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.0391e-04 - val_loss: 5.9113e-04
# Epoch 8/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.1361e-04 - val_loss: 9.9706e-05
# Epoch 9/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.1166e-05 - val_loss: 7.6846e-05
# Epoch 10/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.9154e-05 - val_loss: 3.1339e-05
# Epoch 11/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.2220e-05 - val_loss: 2.5702e-05
# Epoch 12/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.7455e-05 - val_loss: 3.0028e-05
# Epoch 13/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.6807e-05 - val_loss: 1.8464e-05
# Epoch 14/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.8691e-05 - val_loss: 1.5137e-05
# Epoch 15/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.7465e-05 - val_loss: 2.3486e-05
# Epoch 16/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.5989e-05 - val_loss: 1.4722e-05
# Epoch 17/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1655e-05 - val_loss: 2.4974e-05
# Epoch 18/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.6315e-05 - val_loss: 2.8831e-05
# Epoch 19/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.8963e-05 - val_loss: 1.6261e-05
# Epoch 20/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.2139e-05 - val_loss: 1.3124e-05
# Epoch 21/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1329e-05 - val_loss: 1.1686e-05
# Epoch 22/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0637e-05 - val_loss: 1.1555e-05
# Epoch 23/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1205e-05 - val_loss: 2.7810e-05
# Epoch 24/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0648e-05 - val_loss: 2.2443e-05
# Epoch 25/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0429e-05 - val_loss: 2.4202e-05
# Epoch 26/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0385e-05 - val_loss: 1.9292e-05
# Epoch 27/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.1041e-05 - val_loss: 2.2985e-05
# Epoch 28/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4382e-05 - val_loss: 1.5303e-05
# Epoch 29/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6390e-05 - val_loss: 1.1327e-05
# Epoch 30/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0290e-05 - val_loss: 1.5704e-05
# Epoch 31/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7267e-05 - val_loss: 9.7622e-06
# Epoch 32/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2963e-05 - val_loss: 7.6395e-06
# Epoch 33/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3353e-05 - val_loss: 2.7639e-05
# Epoch 34/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6742e-05 - val_loss: 1.0353e-05
# Epoch 35/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5377e-05 - val_loss: 9.7211e-06
# Epoch 36/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2260e-04 - val_loss: 1.6508e-05
# Epoch 37/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.7612e-05 - val_loss: 1.2612e-05
# Epoch 38/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7172e-05 - val_loss: 1.3092e-05
# Epoch 39/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3980e-05 - val_loss: 1.3599e-05
# Epoch 40/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3236e-05 - val_loss: 1.1972e-05
# Epoch 41/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4420e-05 - val_loss: 1.2240e-05
# Epoch 42/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3604e-05 - val_loss: 1.3670e-05
#
# Training model for IMF_4...
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# Epoch 1/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0045 - val_loss: 8.3251e-04
# Epoch 2/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.4457e-04 - val_loss: 8.1943e-04
# Epoch 3/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.1947e-04 - val_loss: 8.5999e-04
# Epoch 4/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.1516e-04 - val_loss: 8.6016e-04
# Epoch 5/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.0644e-04 - val_loss: 8.6692e-04
# Epoch 6/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.0315e-04 - val_loss: 8.5538e-04
# Epoch 7/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.9639e-04 - val_loss: 8.5634e-04
# Epoch 8/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.8964e-04 - val_loss: 8.2859e-04
# Epoch 9/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.5712e-04 - val_loss: 9.2268e-05
# Epoch 10/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.9154e-05 - val_loss: 3.8726e-05
# Epoch 11/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.4793e-05 - val_loss: 3.8374e-05
# Epoch 12/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.5364e-05 - val_loss: 3.9176e-05
# Epoch 13/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.0241e-05 - val_loss: 2.7500e-05
# Epoch 14/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.8834e-05 - val_loss: 3.2423e-05
# Epoch 15/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.2919e-05 - val_loss: 1.7796e-05
# Epoch 16/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.9333e-04 - val_loss: 9.7341e-05
# Epoch 17/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.0763e-05 - val_loss: 4.2660e-05
# Epoch 18/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.3604e-05 - val_loss: 3.9475e-05
# Epoch 19/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.8457e-05 - val_loss: 2.1406e-05
# Epoch 20/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.3640e-05 - val_loss: 1.7430e-05
# Epoch 21/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.0635e-05 - val_loss: 2.6002e-05
# Epoch 22/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.9268e-05 - val_loss: 2.3328e-05
# Epoch 23/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.6718e-05 - val_loss: 1.4938e-05
# Epoch 24/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.6698e-05 - val_loss: 1.3428e-05
# Epoch 25/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.4629e-05 - val_loss: 1.3808e-05
# Epoch 26/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.4273e-05 - val_loss: 2.4745e-05
# Epoch 27/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1617e-05 - val_loss: 1.0227e-05
# Epoch 28/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1613e-05 - val_loss: 1.6704e-05
# Epoch 29/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0667e-05 - val_loss: 1.2182e-05
# Epoch 30/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9411e-05 - val_loss: 1.1546e-05
# Epoch 31/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0212e-05 - val_loss: 1.7588e-05
# Epoch 32/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9251e-05 - val_loss: 7.8573e-06
# Epoch 33/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7010e-04 - val_loss: 1.9918e-04
# Epoch 34/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.4413e-04 - val_loss: 4.9752e-05
# Epoch 35/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.2026e-05 - val_loss: 2.7256e-05
# Epoch 36/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.0386e-05 - val_loss: 4.0664e-05
# Epoch 37/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.0658e-05 - val_loss: 2.1478e-05
# Epoch 38/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.9711e-05 - val_loss: 2.4396e-05
# Epoch 39/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.4777e-05 - val_loss: 2.4820e-05
# Epoch 40/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.3496e-05 - val_loss: 1.3860e-05
# Epoch 41/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.2296e-05 - val_loss: 2.0973e-05
# Epoch 42/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0948e-05 - val_loss: 1.9623e-05
#
# Training model for IMF_5...
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# Epoch 1/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0061 - val_loss: 7.0619e-04
# Epoch 2/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.8360e-04 - val_loss: 7.0687e-04
# Epoch 3/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.4820e-04 - val_loss: 8.0478e-04
# Epoch 4/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.4050e-04 - val_loss: 7.6277e-04
# Epoch 5/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.2545e-04 - val_loss: 7.1417e-04
# Epoch 6/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.1599e-04 - val_loss: 7.1503e-04
# Epoch 7/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.1276e-04 - val_loss: 7.0318e-04
# Epoch 8/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.0877e-04 - val_loss: 7.1116e-04
# Epoch 9/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.9948e-04 - val_loss: 6.9800e-04
# Epoch 10/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.9825e-04 - val_loss: 2.6930e-04
# Epoch 11/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3585e-04 - val_loss: 6.0168e-05
# Epoch 12/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.6605e-05 - val_loss: 2.6492e-05
# Epoch 13/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.0684e-05 - val_loss: 3.0811e-05
# Epoch 14/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.7944e-05 - val_loss: 3.4889e-05
# Epoch 15/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.9249e-04 - val_loss: 2.3813e-04
# Epoch 16/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.8053e-04 - val_loss: 8.5048e-05
# Epoch 17/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3664e-04 - val_loss: 6.7220e-05
# Epoch 18/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.0417e-04 - val_loss: 5.6997e-05
# Epoch 19/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.6123e-05 - val_loss: 5.0475e-05
# Epoch 20/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.5028e-05 - val_loss: 3.9191e-05
# Epoch 21/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.3875e-05 - val_loss: 3.4889e-05
# Epoch 22/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.6123e-05 - val_loss: 4.2593e-05
#
# Training model for IMF_6...
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# Epoch 1/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0045 - val_loss: 4.5199e-04
# Epoch 2/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.7721e-04 - val_loss: 4.5990e-04
# Epoch 3/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.4699e-04 - val_loss: 4.5903e-04
# Epoch 4/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.4156e-04 - val_loss: 4.7934e-04
# Epoch 5/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.3968e-04 - val_loss: 4.9077e-04
# Epoch 6/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.3619e-04 - val_loss: 5.0053e-04
# Epoch 7/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.3180e-04 - val_loss: 4.9750e-04
# Epoch 8/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.2801e-04 - val_loss: 4.7597e-04
# Epoch 9/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.1721e-04 - val_loss: 3.1175e-04
# Epoch 10/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.5981e-04 - val_loss: 1.1384e-04
# Epoch 11/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.3812e-05 - val_loss: 6.8167e-05
# Epoch 12/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.1655e-05 - val_loss: 2.7197e-05
# Epoch 13/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.7547e-05 - val_loss: 2.4178e-05
# Epoch 14/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.2016e-05 - val_loss: 2.4024e-05
# Epoch 15/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.7032e-05 - val_loss: 1.9248e-05
# Epoch 16/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.2607e-05 - val_loss: 1.4820e-05
# Epoch 17/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.9250e-05 - val_loss: 2.0309e-05
# Epoch 18/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.6752e-05 - val_loss: 1.2869e-05
# Epoch 19/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.5254e-05 - val_loss: 1.1723e-05
# Epoch 20/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.5667e-05 - val_loss: 9.8773e-06
# Epoch 21/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.4078e-05 - val_loss: 1.7837e-05
# Epoch 22/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.2674e-05 - val_loss: 1.4226e-05
# Epoch 23/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1979e-05 - val_loss: 1.4126e-05
# Epoch 24/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1367e-05 - val_loss: 9.5927e-06
# Epoch 25/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0790e-05 - val_loss: 1.0972e-05
# Epoch 26/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0178e-05 - val_loss: 7.9516e-06
# Epoch 27/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9276e-05 - val_loss: 7.4946e-06
# Epoch 28/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.8955e-05 - val_loss: 1.0257e-05
# Epoch 29/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.8531e-05 - val_loss: 8.1340e-06
# Epoch 30/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6832e-05 - val_loss: 9.6315e-06
# Epoch 31/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6867e-05 - val_loss: 6.8066e-06
# Epoch 32/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6190e-05 - val_loss: 1.0279e-05
# Epoch 33/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6443e-05 - val_loss: 2.0478e-05
# Epoch 34/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5338e-05 - val_loss: 1.6520e-05
# Epoch 35/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5513e-05 - val_loss: 1.0175e-05
# Epoch 36/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6153e-05 - val_loss: 2.8693e-05
# Epoch 37/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5726e-05 - val_loss: 7.2035e-06
# Epoch 38/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5030e-05 - val_loss: 5.8967e-06
# Epoch 39/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4193e-05 - val_loss: 7.1479e-06
# Epoch 40/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3817e-05 - val_loss: 1.2940e-05
# Epoch 41/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3008e-05 - val_loss: 6.9748e-06
# Epoch 42/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4624e-05 - val_loss: 1.5938e-05
# Epoch 43/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3560e-05 - val_loss: 5.2634e-06
# Epoch 44/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2415e-05 - val_loss: 6.0000e-06
# Epoch 45/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2573e-05 - val_loss: 1.5494e-05
# Epoch 46/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.2179e-04 - val_loss: 1.2741e-04
# Epoch 47/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.4669e-04 - val_loss: 6.3942e-05
# Epoch 48/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.0045e-05 - val_loss: 2.2363e-05
# Epoch 49/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.0983e-05 - val_loss: 2.2041e-05
# Epoch 50/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.1249e-05 - val_loss: 1.7840e-05
# Epoch 51/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.5287e-05 - val_loss: 1.3612e-05
# Epoch 52/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1573e-05 - val_loss: 1.4611e-05
# Epoch 53/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7345e-05 - val_loss: 8.0991e-06
#
# Training model for IMF_7...
# Building model with input shape: (60, 1), num_neurons: 128, dropout_rate: 0.14036310267029162, learning_rate: 0.0007262463191695631
# Epoch 1/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0057 - val_loss: 7.7593e-04
# Epoch 2/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.6216e-04 - val_loss: 7.9089e-04
# Epoch 3/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.3639e-04 - val_loss: 8.0685e-04
# Epoch 4/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.3003e-04 - val_loss: 7.8309e-04
# Epoch 5/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.2439e-04 - val_loss: 7.8717e-04
# Epoch 6/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.1922e-04 - val_loss: 7.7900e-04
# Epoch 7/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.1713e-04 - val_loss: 7.8528e-04
# Epoch 8/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.0886e-04 - val_loss: 4.6712e-04
# Epoch 9/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.9812e-04 - val_loss: 7.7762e-05
# Epoch 10/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.9267e-05 - val_loss: 6.7247e-05
# Epoch 11/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.1799e-05 - val_loss: 4.1700e-05
# Epoch 12/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.8569e-05 - val_loss: 3.3723e-05
# Epoch 13/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.1862e-05 - val_loss: 2.4067e-05
# Epoch 14/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.4394e-05 - val_loss: 2.4760e-05
# Epoch 15/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.6805e-05 - val_loss: 2.1830e-05
# Epoch 16/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 4.2847e-05 - val_loss: 2.6023e-05
# Epoch 17/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.2208e-05 - val_loss: 1.4613e-05
# Epoch 18/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.1215e-05 - val_loss: 1.4740e-05
# Epoch 19/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.9326e-05 - val_loss: 1.9099e-05
# Epoch 20/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.8520e-05 - val_loss: 1.2986e-05
# Epoch 21/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.5976e-05 - val_loss: 2.0073e-05
# Epoch 22/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.4887e-05 - val_loss: 2.1915e-05
# Epoch 23/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.3978e-05 - val_loss: 1.0503e-05
# Epoch 24/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.3030e-05 - val_loss: 9.1855e-06
# Epoch 25/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.5010e-05 - val_loss: 8.9314e-06
# Epoch 26/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9669e-05 - val_loss: 4.0021e-05
# Epoch 27/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.1262e-05 - val_loss: 8.1438e-06
# Epoch 28/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.9519e-05 - val_loss: 9.6978e-06
# Epoch 29/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.8999e-05 - val_loss: 1.4697e-05
# Epoch 30/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 2.0930e-05 - val_loss: 6.8649e-06
# Epoch 31/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7217e-05 - val_loss: 1.6257e-05
# Epoch 32/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7615e-05 - val_loss: 1.3299e-05
# Epoch 33/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6349e-05 - val_loss: 1.7603e-05
# Epoch 34/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.7590e-05 - val_loss: 7.5349e-06
# Epoch 35/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6370e-05 - val_loss: 6.1830e-06
# Epoch 36/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6737e-05 - val_loss: 2.0151e-05
# Epoch 37/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.6294e-05 - val_loss: 7.0657e-06
# Epoch 38/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2525e-05 - val_loss: 7.4333e-06
# Epoch 39/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3940e-05 - val_loss: 4.8708e-05
# Epoch 40/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.5633e-05 - val_loss: 1.1696e-05
# Epoch 41/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.4433e-05 - val_loss: 7.2855e-06
# Epoch 42/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2978e-05 - val_loss: 7.3608e-06
# Epoch 43/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3784e-05 - val_loss: 1.1306e-05
# Epoch 44/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.3018e-05 - val_loss: 5.9585e-06
# Epoch 45/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2545e-05 - val_loss: 8.1094e-06
# Epoch 46/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2643e-05 - val_loss: 5.5147e-06
# Epoch 47/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2565e-05 - val_loss: 8.9710e-06
# Epoch 48/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2498e-05 - val_loss: 5.1251e-06
# Epoch 49/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2139e-05 - val_loss: 9.6628e-06
# Epoch 50/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1998e-05 - val_loss: 4.9906e-06
# Epoch 51/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.2159e-05 - val_loss: 6.1727e-06
# Epoch 52/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1033e-05 - val_loss: 8.5254e-06
# Epoch 53/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.0296e-05 - val_loss: 8.3940e-06
# Epoch 54/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.0433e-05 - val_loss: 6.4222e-06
# Epoch 55/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.0318e-05 - val_loss: 2.9181e-05
# Epoch 56/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.1543e-05 - val_loss: 5.7642e-06
# Epoch 57/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.9040e-06 - val_loss: 8.3766e-06
# Epoch 58/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.9475e-06 - val_loss: 5.3444e-06
# Epoch 59/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.4446e-06 - val_loss: 4.3011e-06
# Epoch 60/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 1.0052e-05 - val_loss: 4.8060e-06
# Epoch 61/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.0872e-06 - val_loss: 9.4016e-06
# Epoch 62/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.5711e-06 - val_loss: 4.6902e-06
# Epoch 63/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 9.0243e-06 - val_loss: 5.4924e-06
# Epoch 64/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.9668e-06 - val_loss: 4.5815e-06
# Epoch 65/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.2692e-06 - val_loss: 7.9449e-06
# Epoch 66/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.5032e-06 - val_loss: 7.3286e-06
# Epoch 67/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.8973e-06 - val_loss: 5.4180e-06
# Epoch 68/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.8496e-06 - val_loss: 4.3660e-06
# Epoch 69/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.3904e-06 - val_loss: 3.8369e-06
# Epoch 70/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 8.4944e-06 - val_loss: 3.2960e-06
# Epoch 71/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.8048e-06 - val_loss: 4.1162e-06
# Epoch 72/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.8968e-06 - val_loss: 3.9285e-06
# Epoch 73/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.4516e-06 - val_loss: 3.9729e-06
# Epoch 74/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.9323e-06 - val_loss: 4.0409e-06
# Epoch 75/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.2284e-06 - val_loss: 4.0202e-06
# Epoch 76/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.6092e-06 - val_loss: 3.7837e-06
# Epoch 77/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.9262e-06 - val_loss: 4.2566e-06
# Epoch 78/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.5037e-06 - val_loss: 3.0192e-06
# Epoch 79/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.1590e-06 - val_loss: 2.8926e-06
# Epoch 80/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.1685e-06 - val_loss: 3.3497e-06
# Epoch 81/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 7.0416e-06 - val_loss: 6.3114e-06
# Epoch 82/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.7764e-06 - val_loss: 3.2743e-06
# Epoch 83/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.7174e-06 - val_loss: 6.1025e-06
# Epoch 84/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.5471e-06 - val_loss: 3.6609e-06
# Epoch 85/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.0035e-06 - val_loss: 6.9083e-06
# Epoch 86/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.5656e-06 - val_loss: 2.8824e-06
# Epoch 87/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.3359e-06 - val_loss: 4.2358e-06
# Epoch 88/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 6.0106e-06 - val_loss: 3.4842e-06
# Epoch 89/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.7530e-06 - val_loss: 4.4733e-06
# Epoch 90/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.6298e-06 - val_loss: 3.7699e-06
# Epoch 91/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.7858e-06 - val_loss: 7.6168e-06
# Epoch 92/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.6976e-06 - val_loss: 4.3570e-06
# Epoch 93/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.6916e-06 - val_loss: 5.6440e-06
# Epoch 94/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.6014e-06 - val_loss: 4.4661e-06
# Epoch 95/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.2540e-06 - val_loss: 7.0407e-06
# Epoch 96/100
# 995/995 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 5.2916e-06 - val_loss: 7.0273e-06

# %%
import joblib

# Save the scalers dictionary
scaler_save_path = "/content/drive/My Drive/Colab Notebooks/EMH/models/scaler_imfs.pkl"
joblib.dump(scaler_imfs, scaler_save_path)
print("Scalers saved successfully to", scaler_save_path)

# Save each model
for i, model in enumerate(models):
    model_save_path = f"/content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_{i}.keras"
    model.save(model_save_path)
    print(f"Model for IMF_{i} saved successfully to {model_save_path}")

# Save decomposed IMF data
vmd_train.to_csv("/content/drive/My Drive/Colab Notebooks/EMH/models/vmd_train.csv")
vmd_val.to_csv("/content/drive/My Drive/Colab Notebooks/EMH/models/vmd_val.csv")
vmd_test.to_csv("/content/drive/My Drive/Colab Notebooks/EMH/models/vmd_test.csv")
print("IMF CSV files saved successfully!")

# Save ground truth labels
np.save("/content/drive/My Drive/Colab Notebooks/EMH/models/y_val.npy", y_val)
np.save("/content/drive/My Drive/Colab Notebooks/EMH/models/y_test.npy", y_test)

# Save evaluation features
np.save("/content/drive/My Drive/Colab Notebooks/EMH/models/X_val.npy", X_val)
np.save("/content/drive/My Drive/Colab Notebooks/EMH/models/X_test.npy", X_test)

print("NumPy arrays for features and labels saved successfully!")
# Out:
# Scalers saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/scaler_imfs.pkl
# Model for IMF_0 saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_0.keras
# Model for IMF_1 saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_1.keras
# Model for IMF_2 saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_2.keras
# Model for IMF_3 saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_3.keras
# Model for IMF_4 saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_4.keras
# Model for IMF_5 saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_5.keras
# Model for IMF_6 saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_6.keras
# Model for IMF_7 saved successfully to /content/drive/My Drive/Colab Notebooks/EMH/models/model_imf_7.keras
# IMF CSV files saved successfully!
# NumPy arrays for features and labels saved successfully!

# %% [markdown]
# ## Evaluation
# ### Val set evaluation

# %%
def safe_predict(models, X_set, scalers):
    """Make predictions without data leakage"""
    pred_imfs = []
    for i, model in enumerate(models):
        pred = model.predict(X_set[:, i, :])
        pred_imfs.append(scalers[f'IMF_{i}'].inverse_transform(pred))
    return np.sum(pred_imfs, axis=0)

# Generate final predictions
y_val_pred = safe_predict(models, X_val, scaler_imfs)
y_test_pred = safe_predict(models, X_test, scaler_imfs)

# Get actual values with proper window offset
actual_val = val_data['Returns%'].values[WINDOW_SIZE:]
actual_test = test_data['Returns%'].values[WINDOW_SIZE:]
# Out:
# 4774/4774 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 4774/4774 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 4774/4774 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 4774/4774 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 4774/4774 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 4774/4774 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 4774/4774 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 4774/4774 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 3182/3182 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 3182/3182 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 3182/3182 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
# 3182/3182 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 3182/3182 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 3182/3182 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
# 3182/3182 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 3182/3182 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step

# %%
# Evaluate on Validation Set

# Error metrics
mae_val = mean_absolute_error(actual_val, y_val_pred)
rmse_val = np.sqrt(mean_squared_error(actual_val, y_val_pred))
mape_val = mean_absolute_percentage_error(actual_val, y_val_pred) * 100

print("Validation Set Metrics:")
print(f"MAE:  {mae_val:.4f}")
print(f"RMSE: {rmse_val:.4f}")
# Out:
# Validation Set Metrics:
# MAE:  0.0184
# RMSE: 0.0285

# %%
# Plot Predicted vs Actual for Validation Set
plt.figure(figsize=(12, 6))
plt.plot(actual_val, label='Actual Validation Returns')
plt.plot(y_val_pred, label='Predicted Validation Returns', linestyle='--')
# plt.title('VMD-AttGRU Forecast vs Actual Returns (Validation Set)')
plt.xlabel('Time Steps')
plt.ylabel('Returns')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test set evaluation

# %%
# Evaluate on Test Set

# Error metrics
actual_test = actual_test[:y_test_pred.shape[0]] # due to 'vmd_test' trimming earlier

mae_test = mean_absolute_error(actual_test, y_test_pred)
rmse_test = np.sqrt(mean_squared_error(actual_test, y_test_pred))
mape_test = mean_absolute_percentage_error(actual_test, y_test_pred) * 100

print("Test Set Metrics:")
print(f"MAE:  {mae_test:.4f}")
print(f"RMSE: {rmse_test:.4f}")
# Out:
# Test Set Metrics:
# MAE:  0.0181
# RMSE: 0.0270

# %%
# Plot Predicted vs Actual for Test Set
plt.figure(figsize=(12, 6))
plt.plot(actual_test, label='Actual Test Returns')
plt.plot(y_test_pred, label='Predicted Test Returns', linestyle='--')
# plt.title('VMD-AttGRU Forecast vs Actual Returns (Test Set)')
plt.xlabel('Time Steps')
plt.ylabel('Returns')
plt.legend()
plt.tight_layout()
plt.show()
